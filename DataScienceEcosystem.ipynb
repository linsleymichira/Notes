# %% [markdown]
# <a href="https://colab.research.google.com/github/linsleymichira/Notes/blob/main/DataScienceEcosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystems are summarized.

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List popular libraries for Data Science
# - List popular tools for Data Science

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. SciPy
# 3. Scikit-learn

# %% [markdown]
# | Data Science Tools |
# ---
# | VS Code |
# | R Studio |
# | Google Colab |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This a simple arithmetic expression to multiply and then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60

print("200 minutes = ", 200 / 60, "hours")
# Out:
# 200 minutes =  3.3333333333333335 hours

# %% [markdown]
# ## Author
# Linsley Michira
